# %% [markdown]
# # Import your class from the src package

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../"))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.data_preparation.financial_data_analyzer import FinancialDataAnalyzer

# %%
tickers = ["TSLA", "BND", "SPY"]
start_date = "2015-07-01"
end_date = "2025-07-31"

# %%
analyzer = FinancialDataAnalyzer(tickers, start_date, end_date)

# %%
analyzer.download_data()
# Out:
# ...
# [*********************100%***********************]  1 of 1 completed
# Downloaded TSLA with 2535 rows
# [*********************100%***********************]  1 of 1 completed
# Downloaded BND with 2535 rows
# [*********************100%***********************]  1 of 1 completed
# Downloaded SPY with 2535 rows

# %%
analyzer.clean_data()
# Out:
# Cleaning data for TSLA...
# Cleaning data for BND...
# Cleaning data for SPY...

# %%
analyzer.feature_engineering()

# %%
analyzer.plot_price_trends()

# %%
analyzer.plot_volatility("TSLA")

# %%
analyzer.run_stationarity_tests()
# Out:
# Testing stationarity for TSLA:
#
# ADF Test: TSLA Adjusted Close
# ADF Statistic: -1.418872005396829
# p-value: 0.5731959514207214
# # Lags Used: 27
# Number of Observations Used: 2507
# => Series is non-stationary
#
# ADF Test: TSLA Daily Returns
# ADF Statistic: -34.68109047254183
# p-value: 0.0
# # Lags Used: 1
# Number of Observations Used: 2532
# => Series is stationary
#
# Testing stationarity for BND:
#
# ADF Test: BND Adjusted Close
# ADF Statistic: -1.536252438897514
# p-value: 0.5155076800340372
# # Lags Used: 13
# Number of Observations Used: 2521
# => Series is non-stationary
#
# ADF Test: BND Daily Returns
# ADF Statistic: -9.889833166780372
# p-value: 3.582374064523792e-17
# # Lags Used: 23
# Number of Observations Used: 2510
# => Series is stationary
#
# Testing stationarity for SPY:
#
# ADF Test: SPY Adjusted Close
# ADF Statistic: 0.6908123438043783
# p-value: 0.9896527194007103
# # Lags Used: 9
# Number of Observations Used: 2525
# => Series is non-stationary
#
# ...

# %%
analyzer.calculate_var_sharpe("TSLA")
# Out:
# TSLA VaR at 5.0%: -0.0547
# TSLA Annualized Sharpe Ratio: 0.7783
# (np.float64(-0.05466309946643584), np.float64(0.7783404141621659))

# %%
analyzer.save_raw_data()
# Out:
# Saved TSLA processed data to ../data/processed\TSLA_processed.csv
# Saved BND processed data to ../data/processed\BND_processed.csv
# Saved SPY processed data to ../data/processed\SPY_processed.csv
