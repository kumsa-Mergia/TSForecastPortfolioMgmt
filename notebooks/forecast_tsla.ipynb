# %% [markdown]
# # Imports & Config

# %%
import os
import sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), "../"))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.forecasting.StockForecaster import *
# from src.forecasting.lstm_model import *

# %%
plt.style.use('ggplot')
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (14, 8)

# %% [markdown]
# # Create forecaster object

# %%
tsla_forecaster = StockForecaster("TSLA", start="2015-01-01")

# %% [markdown]
# # Fetch data

# %%
tsla_forecaster.fetch_data()
# Out:
# Fetching data for TSLA...
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# # Plot price history

# %%
tsla_forecaster.plot_price_history()

# %% [markdown]
# # Stationarity tests

# %%
print("\nStationarity Test - Price:")
tsla_forecaster.check_stationarity(tsla_forecaster.prices)

print("\nStationarity Test - Returns:")
tsla_forecaster.check_stationarity(tsla_forecaster.returns)
# Out:
# Stationarity Test - Price:
# ADF Statistic: -1.2676
# p-value: 0.6439
# Series is non-stationary
#
# Stationarity Test - Returns:
# ADF Statistic: -11.8846
# p-value: 0.0000
# Series is stationary

# %% [markdown]
# # Decompose the series

# %%
tsla_forecaster.decompose_series()

# %% [markdown]
# # Forecast using ARIMA

# %%
tsla_forecaster.forecast_arima()
tsla_forecaster.plot_arima_forecast()
# Out:
# Training ARIMA model...

# %% [markdown]
# # Forecast using LSTM

# %%
tsla_forecaster.forecast_lstm()
tsla_forecaster.plot_lstm_forecast()
# Out:
# Training LSTM model...
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step

# %% [markdown]
#  # 1-year forecast

# %%
tsla_forecaster.forecast_next_year()
